# %% [markdown]
# ### Matrix Size = 11

# %%
results_bfs_1 = [[10, 20], [11, 533], [12, 31], [13, 209], [14, 39], [15, 12], [16, 50], [17, 139], [18, 87], [19, 34], [20, 996]]
results_bfs_2 = [[25, 136], [30, 90], [35, 8], [40, 0], [45, 2], [50, 19], [55, 29], [60, 25], [65, 641], [70, 16], [75, 94], [80, 95], [85, 16], [90, 1138], [95, 2], [100, 1], [105, 67], [110, 2], [115, 17], [120, 82], [125, 2], [130, 32]]

results_bfs_3 = [[150, 0], [200, 9], [250, 0], [300, 0], [350, 1], [400, 0], [450, 69], [500, 56], [550, 162], [600, 2], [650, 62], [700, 5], [750, 36], [800, 21], [850, 423], [900, 3], [950, 56]]

results_dfbnb_1 = [[10, 0], [11, 0], [12, 0], [13, 0], [14, 0], [15, 0], [16, 0], [17, 0], [18, 0], [19, 0], [20, 0]]
results_dfbnb_2 = [[25, 0], [30, 0], [35, 0], [40, 0], [45, 0], [50, 0], [55, 0], [60, 0], [65, 0], [70, 0], [75, 0], [80, 0], [85, 0], [90, 0], [95, 0], [100, 0], [105, 0], [110, 0], [115, 0], [120, 0], [125, 0], [130, 0]]
results_dfbnb_3 = [[150, 0], [200, 0], [250, 0], [300, 0], [350, 0], [400, 0], [450, 0], [500, 0], [550, 0], [600, 0], [650, 0], [700, 0], [750, 0], [800, 0], [850, 0], [900, 0], [950, 0]]

results_zk_bfs_1 = [[10, 0], [11, 0], [12, 0], [13, 0], [14, 0], [15, 0], [16, 0], [17, 0], [18, 0], [19, 0], [20, 0]]
results_zk_bfs_2 = [[25, 0], [30, 0], [35, 0], [40, 0], [45, 0], [50, 0], [55, 0], [60, 0], [65, 0], [70, 0], [75, 0], [80, 0], [85, 0], [90, 0], [95, 0], [100, 0], [105, 0], [110, 0], [115, 0], [120, 0], [125, 0], [130, 0]]

results_zk_bfs_3 = [[150, 0], [200, 0], [250, 0], [300, 0], [350, 0], [400, 0], [450, 0], [500, 0], [550, 0], [600, 0], [650, 0], [700, 0], [750, 0], [800, 0], [850, 0], [900, 0], [950, 0]]

results_zk_dfbnb_1 = [[10, 0], [11, 0], [12, 0], [13, 0], [14, 0], [15, 0], [16, 0], [17, 0], [18, 0], [19, 0], [20, 0]]
results_zk_dfbnb_2 = [[25, 0], [30, 0], [35, 0], [40, 0], [45, 0], [50, 0], [55, 0], [60, 0], [65, 0], [70, 0], [75, 0], [80, 0], [85, 0], [90, 0], [95, 0], [100, 0], [105, 0], [110, 0], [115, 0], [120, 0], [125, 0], [130, 0]]

results_zk_dfbnb_3 = [[150, 0], [200, 0], [250, 0], [300, 0], [350, 0], [400, 0], [450, 0], [500, 0], [550, 0], [600, 0], [650, 0], [700, 0], [750, 0], [800, 0], [850, 0], [900, 0], [950, 0]]

# %%
results_dfbnb = results_dfbnb_1 + results_dfbnb_2 + results_dfbnb_3
results_bfs = results_bfs_1 + results_bfs_2 + results_bfs_3
results_zk_dfbnb = results_zk_dfbnb_1 + results_zk_dfbnb_2 + results_zk_dfbnb_3
results_zk_bfs = results_zk_bfs_1 + results_zk_bfs_2 + results_zk_bfs_3

# %%
results = [i[0] for i in results_dfbnb]
time_dfbnb = [i[1] for i in results_dfbnb]
time_bfs = [i[1] for i in results_bfs]
time_zk_dfbnb = [i[1] for i in results_zk_dfbnb]
time_zk_bfs = [i[1] for i in results_zk_bfs]

# %%
# import sys
# !{sys.executable} -m pip install matplotlib

# %%
import matplotlib.pyplot as plt 
import numpy as np  
# %matplotlib inline
plt.rcParams['figure.figsize'] = [25, 10]
plt.rcParams.update({'font.size': 16})

# %%
# fig = plt.figure()
# ax = plt.axes()
size = 11
plt.plot(results, time_bfs, color = 'blue', label = 'BFS')
plt.plot(results, time_dfbnb, color = 'red', label = 'DFBnB')
plt.plot(results, time_zk_bfs, color = 'purple', label = 'ZK BFS')
plt.plot(results, time_zk_dfbnb, color = 'green', label = 'ZK DFBnB')
plt.xlabel("R Value", fontsize = 18)
plt.ylabel('Time in Seconds', fontsize = 18)
plt.title("Computational time of ATSP Algorithms for 11x11 Matrices", fontsize = 20)
plt.legend()
plt.show()

# %%
# results = [i[0] for i in results_dfbnb_1]
# time_dfbnb = [i[1] for i in results_dfbnb_1]
# time_bfs = [i[1] for i in results_bfs_1]
# time_zk_dfbnb = [i[1] for i in results_zk_dfbnb_1]
# time_zk_bfs = [i[1] for i in results_zk_bfs_1]
# plt.rcParams['figure.figsize'] = [15, 10]
# plt.plot(results, time_bfs, color = 'blue', label = 'BFS')
# plt.plot(results, time_dfbnb, color = 'red', label = 'DFBnB')
# plt.plot(results, time_zk_bfs, color = 'purple', label = 'ZK BFS')
# plt.plot(results, time_zk_dfbnb, color = 'green', label = 'ZK DFBnB')
# plt.xlabel("R Value", fontsize = 16)
# plt.ylabel('Time in Seconds', fontsize = 16)
# plt.title("Computational time of ATSP Algorithms for 11x11 Matrices ", fontsize = 16)
# plt.legend()
# plt.show()

results = [i[0] for i in (results_dfbnb_1 + results_dfbnb_2)]
time_dfbnb = [i[1] for i in (results_dfbnb_1 + results_dfbnb_2)]
time_bfs = [i[1] for i in (results_bfs_1 + results_bfs_2)]
time_zk_dfbnb = [i[1] for i in (results_zk_dfbnb_1 + results_zk_dfbnb_2)]
time_zk_bfs = [i[1] for i in (results_zk_bfs_1 + results_zk_bfs_2)]
plt.rcParams['figure.figsize'] = [15, 10]
plt.plot(results, time_bfs, color = 'blue', label = 'BFS')
plt.plot(results, time_dfbnb, color = 'red', label = 'DFBnB')
plt.plot(results, time_zk_bfs, color = 'purple', label = 'ZK BFS')
plt.plot(results, time_zk_dfbnb, color = 'green', label = 'ZK DFBnB')
plt.xlim(xmin = 0)
plt.xlabel("R Value", fontsize = 18)
plt.ylabel('Time in Seconds', fontsize = 18)
plt.title("Computational time of ATSP Algorithms for 11x11 Matrices with r <= 130", fontsize = 20)
plt.legend()
plt.show()

# %%
# results = [i[0] for i in results_dfbnb_2]
# time_dfbnb = [i[1] for i in results_dfbnb_2]
# time_bfs = [i[1] for i in results_bfs_2]
# time_zk_dfbnb = [i[1] for i in results_zk_dfbnb_2]
# time_zk_bfs = [i[1] for i in results_zk_bfs_2]
# plt.rcParams['figure.figsize'] = [15, 10]
# plt.plot(results, time_bfs, color = 'blue', label = 'BFS')
# plt.plot(results, time_dfbnb, color = 'red', label = 'DFBnB')
# plt.plot(results, time_zk_bfs, color = 'purple', label = 'ZK BFS')
# plt.plot(results, time_zk_dfbnb, color = 'green', label = 'ZK DFBnB')
# plt.xlabel("R Value", fontsize = 16)
# plt.ylabel('Time in Seconds', fontsize = 16)
# plt.legend()
# plt.show()

# %%
# results = [i[0] for i in results_dfbnb_3]
# time_dfbnb = [i[1] for i in results_dfbnb_3]
# time_bfs = [i[1] for i in results_bfs_3]
# time_zk_dfbnb = [i[1] for i in results_zk_dfbnb_3]
# time_zk_bfs = [i[1] for i in results_zk_bfs_3]
# plt.rcParams['figure.figsize'] = [15, 10]
# plt.plot(results, time_bfs, color = 'blue', label = 'BFS')
# plt.plot(results, time_dfbnb, color = 'red', label = 'DFBnB')
# plt.plot(results, time_zk_bfs, color = 'purple', label = 'ZK BFS')
# plt.plot(results, time_zk_dfbnb, color = 'green', label = 'ZK DFBnB')
# plt.xlabel("R Value", fontsize = 16)
# plt.ylabel('Time in Seconds', fontsize = 16)
# plt.legend()
# plt.show()

# %% [markdown]
# ### Matrix Size = 15

# %%
results_dfbnb_1 = [[10, 2], [11, 11], [12, 27], [13, 24], [14, 13], [15, 242], [16, 8], [17, 17], [18, 3], [19, 9], [20, 5]]
results_dfbnb_2 = [[25, 7], [30, 57], [35, 12], [40, 14], [45, 21], [50, 4], [55, 13], [60, 15], [65, 11], [70, 5], [75, 3], [80, 9], [85, 63], [90, 13], [95, 28], [100, 4], [105, 13], [110, 19], [115, 8], [120, 8], [125, 6], [130, 70]]
results_dfbnb_3 = [[150, 39], [200, 3], [250, 33], [300, 1], [350, 2], [400, 3], [450, 68], [500, 8], [550, 26], [600, 61], [650, 4], [700, 10], [750, 14], [800, 4], [850, 4], [900, 15], [950, 9]]


results_zk_bfs_1 = [[10, 0], [11, 0], [12, 0], [13, 0], [14, 0], [15, 0], [16, 0], [17, 0], [18, 0], [19, 0], [20, 0]]
results_zk_bfs_2 =[[25, 0], [30, 0], [35, 0], [40, 0], [45, 0], [50, 0], [55, 0], [60, 0], [65, 0], [70, 0], [75, 0], [80, 0], [85, 0], [90, 0], [95, 0], [100, 0], [105, 0], [110, 0], [115, 0], [120, 0], [125, 0], [130, 0]]


results_zk_bfs_3 = [[150, 0], [200, 0], [250, 0], [300, 0], [350, 0], [400, 0], [450, 0], [500, 0], [550, 0], [600, 0], [650, 0], [700, 0], [750, 0], [800, 0], [850, 0], [900, 0], [950, 0]]


results_zk_dfbnb_1 = [[10, 0], [11, 0], [12, 0], [13, 0], [14, 0], [15, 0], [16, 0], [17, 0], [18, 0], [19, 0], [20, 0]]
results_zk_dfbnb_2 = [[25, 0], [30, 0], [35, 0], [40, 1], [45, 0], [50, 0], [55, 0], [60, 0], [65, 0], [70, 0], [75, 0], [80, 0], [85, 0], [90, 0], [95, 2], [100, 0], [105, 2], [110, 0], [115, 0], [120, 1], [125, 1], [130, 0]]


results_zk_dfbnb_3 = [[150, 0], [200, 0], [250, 1], [300, 0], [350, 0], [400, 0], [450, 0], [500, 1], [550, 0], [600, 0], [650, 0], [700, 0], [750, 0], [800, 0], [850, 0], [900, 3], [950, 0]]

# %%
results_dfbnb = results_dfbnb_1 + results_dfbnb_2 + results_dfbnb_3
results_zk_dfbnb = results_zk_dfbnb_1 + results_zk_dfbnb_2 + results_zk_dfbnb_3
results_zk_bfs = results_zk_bfs_1 + results_zk_bfs_2 + results_zk_bfs_3


results = [i[0] for i in results_dfbnb]
time_dfbnb = [i[1] for i in results_dfbnb]
time_zk_dfbnb = [i[1] for i in results_zk_dfbnb]
time_zk_bfs = [i[1] for i in results_zk_bfs]

size = 15

plt.rcParams['figure.figsize'] = [25, 10]
plt.plot(results, time_dfbnb, color = 'red', label = 'DFBnB')
plt.plot(results, time_zk_bfs, color = 'purple', label = 'ZK BFS')
plt.plot(results, time_zk_dfbnb, color = 'green', label = 'ZK DFBnB')
plt.xlabel("R Value", fontsize = 18)
plt.ylabel('Time in Seconds', fontsize = 18)
plt.title("Computational time of ATSP Algorithms for 15x15 Matrices ", fontsize = 20)
plt.legend()
plt.show()

# %%
# results = [i[0] for i in results_dfbnb_1]
# time_dfbnb = [i[1] for i in results_dfbnb_1]
# time_zk_dfbnb = [i[1] for i in results_zk_dfbnb_1]
# time_zk_bfs = [i[1] for i in results_zk_bfs_1]
# plt.rcParams['figure.figsize'] = [15, 10]
# plt.plot(results, time_dfbnb, color = 'red', label = 'DFBnB')
# plt.plot(results, time_zk_bfs, color = 'purple', label = 'ZK BFS')
# plt.plot(results, time_zk_dfbnb, color = 'green', label = 'ZK DFBnB')
# plt.xlabel("R Value", fontsize = 16)
# plt.ylabel('Time in Seconds', fontsize = 16)
# plt.legend()
# plt.show()
results = [i[0] for i in (results_dfbnb_1 + results_dfbnb_2)]
time_dfbnb = [i[1] for i in (results_dfbnb_1 + results_dfbnb_2)]
time_zk_dfbnb = [i[1] for i in (results_zk_dfbnb_1 + results_zk_dfbnb_2)]
time_zk_bfs = [i[1] for i in (results_zk_bfs_1 + results_zk_bfs_2)]
plt.rcParams['figure.figsize'] = [15, 10]
plt.plot(results, time_dfbnb, color = 'red', label = 'DFBnB')
plt.plot(results, time_zk_bfs, color = 'purple', label = 'ZK BFS')
plt.plot(results, time_zk_dfbnb, color = 'green', label = 'ZK DFBnB')
plt.xlim(xmin = 0)
plt.xlabel("R Value", fontsize = 18)
plt.ylabel('Time in Seconds', fontsize = 18)
plt.title("Computational time of ATSP Algorithms for 15x15 Matrices with r <= 130 ", fontsize = 20)
plt.legend()
plt.show()
# results = [i[0] for i in (results_dfbnb_1 + results_dfbnb_2)]
# time_dfbnb = [i[1] for i in (results_dfbnb_1 + results_dfbnb_2)]
# time_bfs = [i[1] for i in (results_bfs_1 + results_bfs_2)]
# time_zk_dfbnb = [i[1] for i in (results_zk_dfbnb_1 + results_zk_dfbnb_2)]
# time_zk_bfs = [i[1] for i in (results_zk_bfs_1 + results_zk_bfs_2)]

# %%
# results = [i[0] for i in results_dfbnb_2]
# time_dfbnb = [i[1] for i in results_dfbnb_2]
# time_zk_dfbnb = [i[1] for i in results_zk_dfbnb_2]
# time_zk_bfs = [i[1] for i in results_zk_bfs_2]
# plt.rcParams['figure.figsize'] = [15, 10]
# plt.plot(results, time_dfbnb, color = 'red', label = 'DFBnB')
# plt.plot(results, time_zk_bfs, color = 'purple', label = 'ZK BFS')
# plt.plot(results, time_zk_dfbnb, color = 'green', label = 'ZK DFBnB')
# plt.xlabel("R Value", fontsize = 16)
# plt.ylabel('Time in Seconds', fontsize = 16)
# plt.legend()
# plt.show()

# %%
# results = [i[0] for i in results_dfbnb_3]
# time_dfbnb = [i[1] for i in results_dfbnb_3]
# time_zk_dfbnb = [i[1] for i in results_zk_dfbnb_3]
# time_zk_bfs = [i[1] for i in results_zk_bfs_3]
# plt.rcParams['figure.figsize'] = [15, 10]
# plt.plot(results, time_dfbnb, color = 'red', label = 'DFBnB')
# plt.plot(results, time_zk_bfs, color = 'purple', label = 'ZK BFS')
# plt.plot(results, time_zk_dfbnb, color = 'green', label = 'ZK DFBnB')
# plt.xlabel("R Value", fontsize = 16)
# plt.ylabel('Time in Seconds', fontsize = 16)
# plt.legend()
# plt.show()

# %% [markdown]
# ### Matrix Size = 100

# %%
results_zk_bfs_1 = [[1, 0], [2, 24], [3, 1], [4, 4], [5, 24], [6, 5], [7, 4], [8, 0], [9, 46], [10, 36], [11, 83], [12, 19], [13, 166], [14, 89], [15, 193], [16, 26], [17, 20], [18, 22], [19, 646], [20, 127]]

results_zk_bfs_2 =[[25, 154], [30, 190], [35, 0], [40, 41], [45, 38], [50, 92], [55, 7609], [60, 345], [65, 3147], [70, 137], [75, 563], [80, 1120], [85, 1225], [90, 13367], [95, 9], [100, 5], [105, 291], [110, 1023], [115, 237], [120, 188], [125, 6901], [130, 85]]



results_zk_bfs_3 = [[150, 7], [200, 2109], [250, 6], [300, 2], [350, 116], [400, 7], [450, 33], [500, 535], [550, 431], [600, 31], [650, 7109], [700, 50], [750, 4739], [800, 126], [850, 3445], [900, 772], [950, 67]]



results_zk_dfbnb_1 = [[1, 0], [2, 2], [3, 2], [4, 3], [5, 12], [6, 3], [7, 1], [8, 0], [9, 39], [10, 62], [11, 87], [12, 20], [13, 86], [14, 23], [15, 484], [16, 163], [17, 86], [18, 198], [19, 1024], [20, 1040]]

results_zk_dfbnb_2 = [[25, 2364], [30, 9394], [35, 0], [40, 5257], [45, 30], [50, 2002], [55, 11713], [60, 3908], [65, 9143], [70, 4949], [75, 5434], [80, 1691], [85, 3694], [90, 7898], [95, 6868], [100, 6138], [105, 10762], [110, 9110], [115, 4656], [120, 15458], [125, 16481], [130, 9741]]



results_zk_dfbnb_3 = [[150, 14139], [200, 13402], [250, 14399], [300, 25568], [350, 11887], [400, 7922], [450, 8367], [500, 10685], [550, 38308], [600, 10922], [650, 51303], [700, 25953], [750, 6356], [800, 4276], [850, 19607], [900, 31094], [950, 17390]]

# %%
results_zk_dfbnb = results_zk_dfbnb_1 + results_zk_dfbnb_2 + results_zk_dfbnb_3
results_zk_bfs = results_zk_bfs_1 + results_zk_bfs_2 + results_zk_bfs_3


results = [i[0] for i in results_zk_dfbnb]
time_zk_dfbnb = [i[1] for i in results_zk_dfbnb]
time_zk_bfs = [i[1] for i in results_zk_bfs]

size = 100

plt.rcParams['figure.figsize'] = [25, 10]
plt.plot(results, time_zk_bfs, color = 'purple', label = 'ZK BFS')
plt.plot(results, time_zk_dfbnb, color = 'green', label = 'ZK DFBnB')
plt.xlabel("R Value", fontsize = 18)
plt.ylabel('Time in Seconds', fontsize = 18)
plt.title("Computational time of ATSP Algorithms for 100x100 Matrices ", fontsize = 20)
plt.legend()
plt.show()

# %%
# results = [i[0] for i in results_zk_dfbnb_1]
# time_zk_dfbnb = [i[1] for i in results_zk_dfbnb_1]
# time_zk_bfs = [i[1] for i in results_zk_bfs_1]
# plt.rcParams['figure.figsize'] = [15, 10]
# plt.plot(results, time_zk_bfs, color = 'purple', label = 'ZK BFS')
# plt.plot(results, time_zk_dfbnb, color = 'green', label = 'ZK DFBnB')
# plt.xlabel("R Value", fontsize = 16)
# plt.ylabel('Time in Seconds', fontsize = 16)
# plt.legend()
# plt.show()

results = [i[0] for i in (results_zk_dfbnb_1 + results_zk_dfbnb_2)]
time_zk_dfbnb = [i[1] for i in (results_zk_dfbnb_1 + results_zk_dfbnb_2)]
time_zk_bfs = [i[1] for i in (results_zk_bfs_1 + results_zk_bfs_2)]
plt.rcParams['figure.figsize'] = [15, 10]
plt.plot(results, time_zk_bfs, color = 'purple', label = 'ZK BFS')
plt.plot(results, time_zk_dfbnb, color = 'green', label = 'ZK DFBnB')
plt.xlabel("R Value", fontsize = 18)
plt.ylabel('Time in Seconds', fontsize = 18)
plt.title("Computational time of ATSP Algorithms for 100x100 Matrices with r <= 130", fontsize = 20)
plt.legend()
plt.show()

# results = [i[0] for i in (results_dfbnb_1 + results_dfbnb_2)]
# time_dfbnb = [i[1] for i in (results_dfbnb_1 + results_dfbnb_2)]
# time_bfs = [i[1] for i in (results_bfs_1 + results_bfs_2)]
# time_zk_dfbnb = [i[1] for i in (results_zk_dfbnb_1 + results_zk_dfbnb_2)]
# time_zk_bfs = [i[1] for i in (results_zk_bfs_1 + results_zk_bfs_2)]

# %%
# results = [i[0] for i in results_zk_dfbnb_2]
# time_zk_dfbnb = [i[1] for i in results_zk_dfbnb_2]
# time_zk_bfs = [i[1] for i in results_zk_bfs_2]
# plt.rcParams['figure.figsize'] = [15, 10]
# plt.plot(results, time_zk_bfs, color = 'purple', label = 'ZK BFS')
# plt.plot(results, time_zk_dfbnb, color = 'green', label = 'ZK DFBnB')
# plt.xlabel("R Value", fontsize = 16)
# plt.ylabel('Time in Seconds', fontsize = 16)
# plt.legend()
# plt.show()

# %%
# results = [i[0] for i in results_zk_dfbnb_3]
# time_zk_dfbnb = [i[1] for i in results_zk_dfbnb_3]
# time_zk_bfs = [i[1] for i in results_zk_bfs_3]
# plt.rcParams['figure.figsize'] = [15, 10]
# plt.plot(results, time_zk_bfs, color = 'purple', label = 'ZK BFS')
# plt.plot(results, time_zk_dfbnb, color = 'green', label = 'ZK DFBnB')
# plt.xlabel("R Value", fontsize = 16)
# plt.ylabel('Time in Seconds', fontsize = 16)
# plt.legend()
# plt.show()
