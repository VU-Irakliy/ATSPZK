# %% [markdown]
# ### Matrix Size = 100

# %%
import matplotlib.pyplot as plt

# %%
results_1 = [[1, 100.0], [2, 100.0], [3, 100.0], [4, 100.0], [5, 100.0], [6, 100.0], [7, 100.0], [8, 100.0], [9, 100.0], [10, 100.0], [11, 100.0], [12, 100.0], [13, 100.0], [14, 100.0], [15, 100.0], [16, 100.0], [17, 101.0], [18, 101.0], [19, 101.0], [20, 100.0]]

results_2 = [[25, 102.0], [30, 105.0], [35, 113.0], [40, 123.0], [45, 133.0], [50, 135.0], [55, 145.0], [60, 164.0], [65, 164.0], [70, 152.0], [75, 176.0], [80, 185.0], [85, 190.0], [90, 196.0], [95, 200.0], [100, 215.0], [105, 238.0], [110, 234.0], [115, 232.0], [120, 239.0], [125, 245.0], [130, 268.0]]

results_3 = [[150, 308.0], [200, 407.0], [250, 438.0], [300, 504.0], [350, 619.0], [400, 710.0], [450, 718.0], [500, 822.0], [550, 1003.0], [600, 1174.0], [650, 1103.0], [700, 1207.0], [750, 1296.0], [800, 1387.0], [850, 1351.0], [900, 1540.0], [950, 1746.0]]

# %%
results = results_1 + results_2 + results_3

# %%
rs = [i[0] for i in results]
vals = [i[1] for i in results]
plt.rcParams['figure.figsize'] = [20, 10]
plt.rcParams.update({'font.size': 16})
plt.plot(rs, vals, color = 'blue')
plt.xlabel("R Value", fontsize = 16)
plt.ylabel('Minimum Cost', fontsize = 16)
plt.title("Resulting minimum cost of ATSP of 100x100 Matrices", fontsize = 16)
plt.show()
